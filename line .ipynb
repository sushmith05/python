# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,4,1,2]
plt.plot(x,y,color='red',linewidth=4,marker='*',markerfacecolor='blue',markersize=12)
plt.ylim(1,8)
plt.xlim(1,8)
plt.xlabel('x -axis')
plt.ylabel('y -axis')
plt.title('customization')
plt.show()
